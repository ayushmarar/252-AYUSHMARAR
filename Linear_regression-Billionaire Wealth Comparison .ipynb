# %%
import warnings
warnings.simplefilter("ignore")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset =pd.read_csv("billionaires.csv")
dataset.head()
# Out:
#              name  rank  year  company.founded        company.name  \
# 0      Bill Gates     1  1996             1975           Microsoft
# 1      Bill Gates     1  2001             1975           Microsoft
# 2      Bill Gates     1  2014             1975           Microsoft
# 3  Warren Buffett     2  1996             1962  Berkshire Hathaway
# 4  Warren Buffett     2  2001             1962  Berkshire Hathaway
#
#   company.relationship company.sector  demographics.age demographics.gender  \
# 0              founder       Software                40                male
# 1              founder       Software                45                male
# 2              founder       Software                58                male
# 3              founder        Finance                65                male
# 4              founder        Finance                70                male
#
#   location.citizenship location.country code location.region  \
# ...

# %%
dataset.shape
# Out:
# (2614, 16)

# %%
dataset
# Out:
#                 name  rank  year  company.founded  \
# 0         Bill Gates     1  1996             1975
# 1         Bill Gates     1  2001             1975
# 2         Bill Gates     1  2014             1975
# 3     Warren Buffett     2  1996             1962
# 4     Warren Buffett     2  2001             1962
# ...              ...   ...   ...              ...
# 2609     Wu Chung-Yi  1565  2014             1991
# 2610        Wu Xiong  1565  2014             1999
# 2611       Yang Keng  1565  2014                0
# 2612   Zdenek Bakala  1565  2014             1994
# 2613     Zhu Wenchen  1565  2014             1999
#
#                          company.name company.relationship  \
# 0                           Microsoft              founder
# 1                           Microsoft              founder
# 2                           Microsoft              founder
# 3                  Berkshire Hathaway              founder
# 4                  Berkshire Hathaway              founder
# ...

# %%
dataset.plot(x='wealth.worth in billions', y='demographics.age',style='o' )    
plt.title('wealth.worth in billions vs demographics.age')    
plt.xlabel('wealth.worth in billions')    
plt.ylabel('demographics.age')    
plt.show()

# %%
dataset.plot(x='wealth.worth in billions', y='rank',style='o' )    
plt.title('wealth.worth in billions % vs rank')    
plt.xlabel('wealth.worth in billions')    
plt.ylabel('rank')    
plt.show()

# %%
new_set = dataset.drop(['name','year','company.founded','company.name', 'company.relationship', 'company.sector','demographics.gender','location.citizenship','location.country code','location.region','wealth.type','wealth.how.category','wealth.how.industry'], axis=1)

# %%
new_set
# Out:
#       rank  demographics.age  wealth.worth in billions
# 0        1                40                      18.5
# 1        1                45                      58.7
# 2        1                58                      76.0
# 3        2                65                      15.0
# 4        2                70                      32.3
# ...    ...               ...                       ...
# 2609  1565                55                       1.0
# 2610  1565                 0                       1.0
# 2611  1565                53                       1.0
# 2612  1565                53                       1.0
# 2613  1565                48                       1.0
#
# [2614 rows x 3 columns]

# %%
new_set.head()
# Out:
#    rank  demographics.age  wealth.worth in billions
# 0     1                40                      18.5
# 1     1                45                      58.7
# 2     1                58                      76.0
# 3     2                65                      15.0
# 4     2                70                      32.3

# %%
x=new_set.iloc[:,0]

# %%
x.shape
# Out:
# (2614,)

# %%
x=new_set.iloc[:,0].values.reshape(-1,1)

# %%
x.shape
# Out:
# (2614, 1)

# %%
x
# Out:
# array([[   1],
#        [   1],
#        [   1],
#        ...,
#        [1565],
#        [1565],
#        [1565]], dtype=int64)

# %%
y = new_set.iloc[:,1]

# %%
y.shape
# Out:
# (2614,)

# %%
y=new_set.iloc[:,1].values.reshape(-1,1)

# %%
y
# Out:
# array([[40],
#        [45],
#        [58],
#        ...,
#        [53],
#        [53],
#        [48]], dtype=int64)

# %%
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (2091, 1)

# %%
x_test.shape
# Out:
# (523, 1)

# %%
y_train.shape
# Out:
# (2091, 1)

# %%
y_test.shape
# Out:
# (523, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([[52.2440661 ],
#        [60.38065471],
#        [60.18871467],
#        [55.40690413],
#        [58.87017005],
#        [56.88400791],
#        [52.2440661 ],
#        [49.87402388],
#        [59.60454933],
#        [55.92430772],
#        [50.20783264],
#        [50.04927348],
#        [51.38450854],
#        [53.5125394 ],
#        [49.41503683],
#        [49.7488456 ],
#        [49.38165596],
#        [59.60454933],
#        [58.25262384],
#        [60.38065471],
#        [50.89214061],
#        [58.87017005],
#        [50.59171272],
#        [60.38065471],
#        [51.39285375],
#        [58.87017005],
#        [48.59720536],
#        [48.78080018],
#        [58.25262384],
#        [55.92430772],
#        [53.23714717],
#        [51.92694778],
#        [49.03950197],
#        [50.21617786],
#        [51.92694778],
#        [50.95890236],
#        [55.06475015],
#        [57.26788799],
#        [51.74335296],
#        [48.964395  ],
#        [51.66824598],
# ...

# %%
plt.scatter(x,y, color = 'yellow')
plt.plot(x_test,y_pred, color = 'blue')
